# %% [markdown]
# # Import Libraries

# %%
#Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read Dataset

# %%
#Read dataset
data = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding = 'latin-1')

# %%
data
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %% [markdown]
# # What is the total number and percentage of missing data in 2014 to 3 decimal places?

# %%
data.isna().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %% [markdown]
# # Perform a groupby operation on ‘Element’.  What year has the highest sum of Stock Variation?

# %%
x = data.groupby('Element').get_group('Stock Variation')

# %%
x
# Out:
#        Area Code      Area  Item Code                      Item  Element Code  \
# 13             4   Algeria       2905  Cereals - Excluding Beer          5072
# 29             4   Algeria       2511        Wheat and products          5072
# 45             4   Algeria       2805         Rice and products          5072
# 60             4   Algeria       2513       Barley and products          5072
# 75             4   Algeria       2514        Maize and products          5072
# ...          ...       ...        ...                       ...           ...
# 60842        181  Zimbabwe       2763              Pelagic Fish          5072
# 60853        181  Zimbabwe       2764        Marine Fish, Other          5072
# 60914        181  Zimbabwe       2928             Miscellaneous          5072
# 60924        181  Zimbabwe       2680               Infant food          5072
# 60934        181  Zimbabwe       2899             Miscellaneous          5072
#
# ...

# %%
x.sum(axis = 0, skipna = True)
# Out:
# Area Code                                                  571566
# Area            AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Item Code                                                11329527
# Item            Cereals - Excluding BeerWheat and productsRice...
# Element Code                                             21464704
# Element         Stock VariationStock VariationStock VariationS...
# Unit            1000 tonnes1000 tonnes1000 tonnes1000 tonnes10...
# Y2014                                                     58749.8
# Y2015                                                       34911
# Y2016                                                     33140.1
# Y2017                                                     54316.9
# Y2018                                                     20577.9
# dtype: object

# %% [markdown]
# # What is the mean and standard deviation across the whole dataset for the year 2017 to 2 decimal places?

# %%
data.describe(include='all')
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %% [markdown]
# # Which year had the least correlation with ‘Element Code’?

# %%
#Least correlation with Element code
plt.subplots(figsize=(15,15))
sns.heatmap(data.corr(), annot = True)
plt.xticks(rotation = 90)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5]),
#  <a list of 8 Text major ticklabel objects>)

# %% [markdown]
# # What is the total number of unique countries in the dataset?

# %%
size = data.groupby('Area')['Area'].count()

# %%
size.shape
# Out:
# (49,)

# %% [markdown]
# # Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’.  Which of these Areas had the highest sum in 2017?

# %%
y = data.groupby('Area')['Y2017'].count()

# %%
y
# Out:
# Area
# Algeria                        1279
# Angola                         1407
# Benin                          1253
# Botswana                       1368
# Burkina Faso                   1383
# Cabo Verde                     1193
# Cameroon                       1441
# Central African Republic       1262
# Chad                           1281
# Comoros                          45
# Congo                          1395
# Côte d'Ivoire                  1454
# Djibouti                       1061
# Egypt                          1458
# Eswatini                       1251
# Ethiopia                       1428
# Ethiopia PDR                     39
# Gabon                          1206
# Gambia                         1116
# Ghana                          1333
# Guinea                         1383
# Guinea-Bissau                  1076
# Kenya                          1548
# Lesotho                        1110
# Liberia                        1135
# Madagascar                     1425
# ...

# %% [markdown]
# # Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’.  Which of these Areas had the 7th lowest sum in 2017?

# %%
p = data.groupby('Area')['Y2017'].count()

# %%
p
# Out:
# Area
# Algeria                        1279
# Angola                         1407
# Benin                          1253
# Botswana                       1368
# Burkina Faso                   1383
# Cabo Verde                     1193
# Cameroon                       1441
# Central African Republic       1262
# Chad                           1281
# Comoros                          45
# Congo                          1395
# Côte d'Ivoire                  1454
# Djibouti                       1061
# Egypt                          1458
# Eswatini                       1251
# Ethiopia                       1428
# Ethiopia PDR                     39
# Gabon                          1206
# Gambia                         1116
# Ghana                          1333
# Guinea                         1383
# Guinea-Bissau                  1076
# Kenya                          1548
# Lesotho                        1110
# Liberia                        1135
# Madagascar                     1425
# ...

# %% [markdown]
# # What is the total sum of Wine produced in 2015 and 2018 respectively?

# %%
q = data.groupby('Item').get_group('Wine')

# %%
q
# Out:
#        Area Code      Area  Item Code  Item  Element Code  \
# 916            4   Algeria       2655  Wine          5511
# 917            4   Algeria       2655  Wine          5611
# 918            4   Algeria       2655  Wine          5072
# 919            4   Algeria       2655  Wine          5911
# 920            4   Algeria       2655  Wine          5301
# ...          ...       ...        ...   ...           ...
# 60551        181  Zimbabwe       2655  Wine          5142
# 60552        181  Zimbabwe       2655  Wine           645
# 60553        181  Zimbabwe       2655  Wine           664
# 60554        181  Zimbabwe       2655  Wine           674
# 60555        181  Zimbabwe       2655  Wine           684
#
#                                       Element             Unit  Y2014  Y2015  \
# 916                                Production      1000 tonnes  52.00   10.0
# 917                           Import Quantity      1000 tonnes   7.00    8.0
# ...

# %%
q.sum(axis = 0, skipna = True)
# Out:
# Area Code                                                   66206
# Area            AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Item Code                                                 1319535
# Item            WineWineWineWineWineWineWineWineWineWineWineWi...
# Element Code                                              1818328
# Element         ProductionImport QuantityStock VariationExport...
# Unit            1000 tonnes1000 tonnes1000 tonnes1000 tonnes10...
# Y2014                                                     4497.36
# Y2015                                                     4251.81
# Y2016                                                     3872.09
# Y2017                                                     4178.02
# Y2018                                                     4039.32
# dtype: object

# %% [markdown]
# # What is the total Protein supply quantity in Madagascar in 2015?

# %%
r = data.groupby('Element').get_group('Protein supply quantity (g/capita/day)')

# %%
r
# Out:
#        Area Code      Area  Item Code                      Item  Element Code  \
# 3              4   Algeria       2901               Grand Total           674
# 6              4   Algeria       2903          Vegetal Products           674
# 9              4   Algeria       2941           Animal Products           674
# 25             4   Algeria       2905  Cereals - Excluding Beer           674
# 41             4   Algeria       2511        Wheat and products           674
# ...          ...       ...        ...                       ...           ...
# 60903        181  Zimbabwe       2769   Aquatic Animals, Others           674
# 60911        181  Zimbabwe       2775            Aquatic Plants           674
# 60921        181  Zimbabwe       2928             Miscellaneous           674
# 60931        181  Zimbabwe       2680               Infant food           674
# 60941        181  Zimbabwe       2899             Miscellaneous           674
#
# ...

# %%
r.sum(axis = 0, skipna = True)
# Out:
# Area Code                                                  675050
# Area            AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Item Code                                                13535000
# Item            Grand TotalVegetal ProductsAnimal ProductsCere...
# Element Code                                              3385502
# Element         Protein supply quantity (g/capita/day)Protein ...
# Unit            g/capita/dayg/capita/dayg/capita/dayg/capita/d...
# Y2014                                                     11836.5
# Y2015                                                       11834
# Y2016                                                     11779.7
# Y2017                                                     11842.5
# Y2018                                                     11833.6
# dtype: object

# %%
s = data.groupby('Area')['Area'].count()

# %%
s
# Out:
# Area
# Algeria                        1313
# Angola                         1424
# Benin                          1285
# Botswana                       1378
# Burkina Faso                   1409
# Cabo Verde                     1260
# Cameroon                       1460
# Central African Republic       1344
# Chad                           1343
# Comoros                          45
# Congo                          1413
# Côte d'Ivoire                  1467
# Djibouti                       1095
# Egypt                          1488
# Eswatini                       1284
# Ethiopia                       1447
# Ethiopia PDR                     39
# Gabon                          1245
# Gambia                         1168
# Ghana                          1354
# Guinea                         1410
# Guinea-Bissau                  1128
# Kenya                          1560
# Lesotho                        1150
# Liberia                        1206
# Madagascar                     1439
# ...

# %% [markdown]
# # Perform a groupby operation on ‘Element’.  What is the total number of the sum of Processing in 2017?

# %%
t = data.groupby('Element').get_group('Processing')

# %%
t
# Out:
#        Area Code      Area  Item Code                      Item  Element Code  \
# 19             4   Algeria       2905  Cereals - Excluding Beer          5131
# 35             4   Algeria       2511        Wheat and products          5131
# 51             4   Algeria       2805         Rice and products          5131
# 66             4   Algeria       2513       Barley and products          5131
# 81             4   Algeria       2514        Maize and products          5131
# ...          ...       ...        ...                       ...           ...
# 60694        181  Zimbabwe       2946               Animal fats          5131
# 60717        181  Zimbabwe       2743                     Cream          5131
# 60730        181  Zimbabwe       2737        Fats, Animals, Raw          5131
# 60789        181  Zimbabwe       2948   Milk - Excluding Butter          5131
# 60803        181  Zimbabwe       2848   Milk - Excluding Butter          5131
#
# ...

# %%
t.sum(axis = 0, skipna = True)
# Out:
# Area Code                                                  271940
# Area            AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Item Code                                                 5350416
# Item            Cereals - Excluding BeerWheat and productsRice...
# Element Code                                             10313310
# Element         ProcessingProcessingProcessingProcessingProces...
# Unit            1000 tonnes1000 tonnes1000 tonnes1000 tonnes10...
# Y2014                                                      282923
# Y2015                                                      287929
# Y2016                                                      280631
# Y2017                                                      292836
# Y2018                                                      308429
# dtype: object
